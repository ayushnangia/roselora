# %% [markdown]
# # RoseLoRA: Row and Column-wise Sparse Low-rank Adaptation
#
# This notebook allows you to run the official implementation of RoseLoRA from the EMNLP'24 paper: [RoseLoRA: Row and Column-wise Sparse Low-rank Adaptation of Pre-trained Language Model for Knowledge Editing and Fine-tuning](https://arxiv.org/abs/2406.10777)

# %%
# !nvidia-smi
# Out:
# Fri Apr 11 11:55:43 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !git clone https://github.com/ayushnangia/roselora
# %cd roselora
# Out:
# Cloning into 'roselora'...
# remote: Enumerating objects: 144, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 144 (delta 26), reused 124 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (144/144), 14.69 MiB | 3.90 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# Updating files: 100% (98/98), done.
# /content/roselora

# %%
# !pip install  -r requirements.txt
# Out:
# Requirement already satisfied: einops>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (0.8.1)
# Collecting gpustat>=1.1 (from -r requirements.txt (line 2))
#   Downloading gpustat-1.1.1.tar.gz (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 5.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting hydra-core>=1.1.1 (from -r requirements.txt (line 3))
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting higher>=0.2.1 (from -r requirements.txt (line 4))
#   Downloading higher-0.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib-metadata>=6.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (8.6.1)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.9.1)
# Collecting omegaconf>=2.1.1 (from -r requirements.txt (line 7))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.6.1)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (1.14.1)
# Requirement already satisfied: sentence-transformers>=2.2.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (0.21.1)
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (4.67.1)
# Requirement already satisfied: transformers>=4.40.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (4.50.3)
# Requirement already satisfied: openai>=0.27.9 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (1.70.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (0.14.0)
# Requirement already satisfied: timm>=0.9.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (1.0.15)
# Collecting iopath>=0.1.10 (from -r requirements.txt (line 20))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: opencv-python>=4.8.0.76 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (4.11.0.86)
# Collecting fairscale>=0.4.13 (from -r requirements.txt (line 22))
#   Downloading fairscale-0.4.13.tar.gz (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 20.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (5.29.4)
# Requirement already satisfied: matplotlib>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (3.10.0)
# Collecting ipywidgets>=8.1.1 (from -r requirements.txt (line 29))
#   Downloading ipywidgets-8.1.6-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: plotnine>=0.12.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 30)) (0.14.5)
# Requirement already satisfied: huggingface-hub>=0.20.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (0.30.1)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (2.0.2)
# Requirement already satisfied: accelerate>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (1.5.2)
# Requirement already satisfied: sentencepiece>=0.1.96 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 34)) (0.2.0)
# Collecting evaluate>=0.4.1 (from -r requirements.txt (line 35))
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.18.0 (from -r requirements.txt (line 36))
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 37)) (0.19.9)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /usr/local/lib/python3.11/dist-packages (from gpustat>=1.1->-r requirements.txt (line 2)) (12.570.86)
# Requirement already satisfied: psutil>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from gpustat>=1.1->-r requirements.txt (line 2)) (5.9.5)
# Collecting blessed>=1.17.1 (from gpustat>=1.1->-r requirements.txt (line 2))
#   Downloading blessed-1.20.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1.1->-r requirements.txt (line 3))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.1.1->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.3.0->-r requirements.txt (line 5)) (3.21.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.5->-r requirements.txt (line 6)) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.5->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.5->-r requirements.txt (line 6)) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.2.2->-r requirements.txt (line 12)) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r requirements.txt (line 14)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.1->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->-r requirements.txt (line 16)) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->-r requirements.txt (line 16)) (0.5.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.9->-r requirements.txt (line 17)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.9->-r requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.9->-r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.9->-r requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.9->-r requirements.txt (line 17)) (2.11.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.9->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm>=0.9.7->-r requirements.txt (line 19)) (0.21.0+cu124)
# Collecting portalocker (from iopath>=0.1.10->-r requirements.txt (line 20))
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.4->-r requirements.txt (line 28)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.4->-r requirements.txt (line 28)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.4->-r requirements.txt (line 28)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.4->-r requirements.txt (line 28)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.4->-r requirements.txt (line 28)) (3.2.3)
# Collecting comm>=0.1.3 (from ipywidgets>=8.1.1->-r requirements.txt (line 29))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.1->-r requirements.txt (line 29)) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.1->-r requirements.txt (line 29)) (5.7.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=8.1.1->-r requirements.txt (line 29))
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.14 (from ipywidgets>=8.1.1->-r requirements.txt (line 29))
#   Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: mizani~=0.13.0 in /usr/local/lib/python3.11/dist-packages (from plotnine>=0.12.4->-r requirements.txt (line 30)) (0.13.2)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from plotnine>=0.12.4->-r requirements.txt (line 30)) (0.14.4)
# Collecting dill (from evaluate>=0.4.1->-r requirements.txt (line 35))
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from evaluate>=0.4.1->-r requirements.txt (line 35))
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate>=0.4.1->-r requirements.txt (line 35))
#   Downloading multiprocess-0.70.17-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.18.0->-r requirements.txt (line 36)) (18.1.0)
# Collecting dill (from evaluate>=0.4.1->-r requirements.txt (line 35))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate>=0.4.1->-r requirements.txt (line 35))
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch>=2.0.1->-r requirements.txt (line 14))
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.18.0->-r requirements.txt (line 36)) (3.11.15)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 37)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 37)) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 37)) (4.3.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 37)) (2.25.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 37)) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 37)) (75.2.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=0.27.9->-r requirements.txt (line 17)) (3.10)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.11/dist-packages (from blessed>=1.17.1->gpustat>=1.1->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from blessed>=1.17.1->gpustat>=1.1->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.18.0->-r requirements.txt (line 36)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.18.0->-r requirements.txt (line 36)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.18.0->-r requirements.txt (line 36)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.18.0->-r requirements.txt (line 36)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.18.0->-r requirements.txt (line 36)) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.18.0->-r requirements.txt (line 36)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.18.0->-r requirements.txt (line 36)) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 37)) (4.0.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=0.27.9->-r requirements.txt (line 17)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=0.27.9->-r requirements.txt (line 17)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.27.9->-r requirements.txt (line 17)) (0.14.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai>=0.27.9->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai>=0.27.9->-r requirements.txt (line 17)) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai>=0.27.9->-r requirements.txt (line 17)) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.40.0->-r requirements.txt (line 16)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.40.0->-r requirements.txt (line 16)) (2.3.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.14.0->plotnine>=0.12.4->-r requirements.txt (line 30)) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.1->-r requirements.txt (line 14)) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 37)) (5.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.1->-r requirements.txt (line 29)) (0.7.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.8 MB/s eta 0:00:00
# Downloading higher-0.2.1-py3-none-any.whl (27 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.8 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.6-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 13.3 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.5 MB/s eta 0:00:00
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 39.4 MB/s eta 0:00:00
# Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.5 MB/s eta 0:00:00
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.0 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 17.6 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.0/214.0 kB 20.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.4 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 91.8 MB/s eta 0:00:00
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.4 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.4 MB/s eta 0:00:00
# Building wheels for collected packages: gpustat, antlr4-python3-runtime, iopath, fairscale
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26666 sha256=9a8888e7c788dca86dea15e85b283ebdcc99566239a69eca8285d9cea0dd3b74
#   Stored in directory: /root/.cache/pip/wheels/c9/2b/d9/a0b77d6e8623ce6b5c73813af455a3ace394abfc2e8aef7ed6
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=e9729aaaded2e8193f058a1af25ebf7b7916af7dedddd61e2bf37080e108967f
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=b6f5b8461b4afeeb47449bf5efd3a7eef246e8b6fc6caf285907571bd9c1ace1
#   Stored in directory: /root/.cache/pip/wheels/ba/5e/16/6117f8fe7e9c0c161a795e10d94645ebcf301ccbd01f66d8ec
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.13-py3-none-any.whl size=332207 sha256=38f09ab5aaedfb0cbffc379416e4d0b7b64a46801223026495593b1dea6656b7
#   Stored in directory: /root/.cache/pip/wheels/95/ef/96/5044bde220b2ea299bdc6ec05051e0ef187fad45b341d1c273
# Successfully built gpustat antlr4-python3-runtime iopath fairscale
# Installing collected packages: antlr4-python3-runtime, xxhash, widgetsnbextension, portalocker, omegaconf, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jupyterlab_widgets, jedi, fsspec, dill, comm, blessed, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, iopath, hydra-core, gpustat, nvidia-cusolver-cu12, ipywidgets, datasets, higher, fairscale, evaluate
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: jupyterlab_widgets
#     Found existing installation: jupyterlab_widgets 3.0.13
#     Uninstalling jupyterlab_widgets-3.0.13:
#       Successfully uninstalled jupyterlab_widgets-3.0.13
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 blessed-1.20.0 comm-0.2.2 datasets-3.5.0 dill-0.3.8 evaluate-0.4.3 fairscale-0.4.13 fsspec-2024.12.0 gpustat-1.1.1 higher-0.2.1 hydra-core-1.3.2 iopath-0.1.10 ipywidgets-8.1.6 jedi-0.19.2 jupyterlab_widgets-3.0.14 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 omegaconf-2.3.0 portalocker-3.1.1 widgetsnbextension-4.0.14 xxhash-3.5.0

# %%
import os

# Parameters that can be adjusted
data_size = -1  # How many samples to test with. Set to -1 to use all samples
sequential_edit = 1  # Sequential editing length
retrain = 0  # Whether to enforce retrain. Set to 0 to use existing results if available
base_model = "llama2"  # LLM to edit. Currently only supports "llama2"

# Set CUDA device
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

print(f"Parameters:\n"
      f"- Data size: {data_size}\n"
      f"- Sequential edit: {sequential_edit}\n"
      f"- Retrain: {retrain}\n"
      f"- Base model: {base_model}")
# Out:
# Parameters:
# - Data size: -1
# - Sequential edit: 1
# - Retrain: 0
# - Base model: llama2

# %%
from huggingface_hub import login

# Enter your HuggingFace token to access LLaMA-2 model
# You can get this token from https://huggingface.co/settings/tokens
from google.colab import userdata
hf_token = input("Enter your HuggingFace token to access LLaMA-2 model: ")
login(token=userdata.get('HF_TOKEN'))

# %%
import sys
sys.path.append('.')
# !cd ./roselora/examples && python run_zsre.py \
    --editing_method RoseLoRA \
    --ds_size {data_size} \
    --sequential_edit {sequential_edit} \
    --retrain {retrain} \
    --data_dir=/content/roselora/examples/data/ZsRE \
    --hparams_dir=../hparams/RoseLoRA/llama-7b \
    --base_model={base_model}
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/hub.py:4: FutureWarning: Importing from timm.models.hub is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# 2025-04-11 12:09:31.208060: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744373371.440110    4276 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744373371.504117    4276 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-11 12:09:31.996070: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# See results at:  output/RoseLoRA/Llama-2-7b-chat-hf_RoseLoRA_N=1037S=1.json
# Loading checkpoint shards:  50% 1/2 [00:43<00:43, 43.34s/it]^C

# %%
# List output files
# !ls -la ./roselora/examples/output/RoseLoRA

# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# Find the most recent results file
output_dir = "./roselora/examples/output/RoseLoRA"
if os.path.exists(output_dir):
    result_files = [f for f in os.listdir(output_dir) if f.endswith(".json") and not f.startswith(".")]
    if result_files:
        latest_file = sorted(result_files)[-1]
        result_path = os.path.join(output_dir, latest_file)
        print(f"Analyzing results from: {result_path}")

        with open(result_path, 'r') as f:
            results = json.load(f)

        # Extract metrics
        edit_success = [data['post']['rewrite_acc'][0] for data in results]
        rephrase_success = [data['post']['rephrase_acc'][0] for data in results]

        # Calculate averages
        avg_edit_success = sum(edit_success) / len(edit_success) * 100
        avg_rephrase_success = sum(rephrase_success) / len(rephrase_success) * 100

        # Extract portability and locality metrics
        portability_values = []
        locality_values = []

        for data in results:
            # Portability
            port_case_list = []
            for key in data['post']['portability'].keys():
                port_vals = data['post']['portability'][key]
                if port_vals:
                    port_case_list.append(sum(port_vals) / len(port_vals) * 100)
            if port_case_list:
                portability_values.append(np.mean(port_case_list))

            # Locality
            loc_case_list = []
            for key in data['post']['locality'].keys():
                loc_vals = data['post']['locality'][key]
                if loc_vals:
                    loc_case_list.append(sum(loc_vals) / len(loc_vals) * 100)
            if loc_case_list:
                locality_values.append(np.mean(loc_case_list))

        # Calculate averages
        avg_portability = np.mean(portability_values) if portability_values else 0
        avg_locality = np.mean(locality_values) if locality_values else 0

        # Plot results
        metrics = ['Edit Success', 'Rephrase Success', 'Portability', 'Locality']
        values = [avg_edit_success, avg_rephrase_success, avg_portability, avg_locality]

        plt.figure(figsize=(10, 6))
        plt.bar(metrics, values, color=['blue', 'green', 'red', 'purple'])
        plt.ylabel('Percentage (%)')
        plt.title('RoseLoRA Performance Metrics')
        plt.ylim(0, 100)

        # Add value labels on bars
        for i, v in enumerate(values):
            plt.text(i, v + 2, f"{v:.2f}%", ha='center')

        plt.show()

        print(f"Edit Success: {avg_edit_success:.2f}%")
        print(f"Rephrase Success: {avg_rephrase_success:.2f}%")
        print(f"Portability: {avg_portability:.2f}%")
        print(f"Locality: {avg_locality:.2f}%")
    else:
        print("No result files found.")
else:
    print(f"Output directory {output_dir} not found.")

# %%
# Display current hyperparameters
# !cat hparams/RoseLoRA/llama-7b.yaml

# %%
# Function to modify sparsity parameter
import fileinput
import sys

def modify_sparsity(new_sparsity=0.05):
    file_path = 'easyeditor/models/roselora/roselora_main.py'
    for line in fileinput.input(file_path, inplace=True):
        if 'sparsity = ' in line and not line.strip().startswith('#'):
            sys.stdout.write(f"    sparsity = {new_sparsity}  # Modified from original value\n")
        else:
            sys.stdout.write(line)
    print(f"Changed sparsity to {new_sparsity}")

# Uncomment the next line to modify sparsity
# modify_sparsity(0.1)  # Change to your desired value
